# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = "/iphone_purchase_records - iphone_purchase_records.csv"

dataset = pd.read_csv(path)

# %%
dataset.head()
# Out:
#    Gender  Age  Salary  Purchase Iphone
# 0    Male   19   19000                0
# 1    Male   35   20000                0
# 2  Female   26   43000                0
# 3  Female   27   57000                0
# 4    Male   19   76000                0

# %%
dataset['log_Sal'] = np.log(dataset['Salary'])

# %%
dataset.head()
# Out:
#    Gender  Age  Salary  Purchase Iphone    log_Sal
# 0    Male   19   19000                0   9.852194
# 1    Male   35   20000                0   9.903488
# 2  Female   26   43000                0  10.668955
# 3  Female   27   57000                0  10.950807
# 4    Male   19   76000                0  11.238489

# %%
sns.swarmplot(
    y='Salary',
    x='Purchase Iphone',
    hue='Gender',
    data=dataset
)

plt.show()

# %%
sns.countplot(
    x='Gender',
    hue='Purchase Iphone',
    data=dataset
)

plt.show()

# %%
sns.scatterplot(x='Age', y='Salary', hue='Purchase Iphone', data=dataset)
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %%
X = np.array(dataset[['Gender','log_Age','log_Sal']])
y = np.array(dataset['Purchase Iphone'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1588212863.py in <cell line: 0>()
# ----> 1 X = np.array(dataset[['Gender','log_Age','log_Sal']])
#       2 y = np.array(dataset['Purchase Iphone'])
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# ...
